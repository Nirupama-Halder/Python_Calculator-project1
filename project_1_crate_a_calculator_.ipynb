# %% [markdown]
# <a href="https://colab.research.google.com/github/Nirupama-Halder/Python_Calculator-project1/blob/main/project_1_crate_a_calculator_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MINI** **CALCULATOR**

# %%
def calculator():
  try:
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))
  except ValueError:
    print("Invalid input. Please enter a valid number.")
    return

  operator = input("Enter operator: (+,-,*,/):")
  if operator == "+":
    print("Rasults:",num1 + num2)
  elif operator == "-":
      print("Rasults:",num1 - num2)
  elif operator == "*":
      print("Rasults:",num1 * num2)
  elif operator == "/":
    if num2 == 0:
      print("cannot divide by Zero")
    else:
        print("Rasults:",num1 / num2)
  else:
    print("Invalid operator")

while True:
    calculator()
    choice = input("continue? (y/n):")
    if choice.lower()!= "y":
      break
print("Calculator Closed")
# Out:
# Enter first number: 10
# Enter second number: 20
# Enter operator: (+,-,*,/):*
# Rasults: 200.0
# continue? (y/n):n
# Calculator Closed
